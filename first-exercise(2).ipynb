# %%
x= {2,2,2,3,3,3,5,7,8,9,10,11,11,13,13,15,16,17,18,18,18}
y= {1,2,2,2,6,6,6,8,8,8,10,10,10,12,12,19,19,18,21,22,22}
z= {3,1,1,1,4,4,6,6,8,8,9,16,13,13,13,16,20,22,23,23,23}
import matplotlib.pyplot as plt
plt.hist(x)
plt.hist(y)
plt.hist(z)
plt.show()
